# %% [markdown]
# # 04 — Few-shot node classification
#
# 1-shot and 5-shot node classification on the four downstream datasets. Reproduces Table 3.

# %%
import os, sys
REPO = '/content/QuantAI'
sys.path.insert(0, os.path.join(REPO, 'src'))
os.environ['RIEMANN_GFM_DATA_ROOT'] = '/content/drive/MyDrive/RiemannGFM/data'
# %cd $REPO

# %%
CKPT = '/content/drive/MyDrive/RiemannGFM/checkpoints/riemann_gfm.pt'
for ds in ['citeseer', 'pubmed', 'github', 'airports']:
    for k in [1, 5]:
        # !python main.py fewshot --dataset $ds --k $k --checkpoint $CKPT

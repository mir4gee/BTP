# %% [markdown]
# # 01 — Pre-train RiemannGFM
#
# Reproduces the pre-training run from `scripts/pretrain.sh` on ogbn-arxiv + Physics + Amazon-Computers.
#
# Runtime: T4 GPU, ~2–3 hours. Checkpoint is saved to Drive.

# %%
# Run 00_install.ipynb first if this is a fresh session.
import os, sys
REPO = '/content/QuantAI'
assert os.path.isdir(REPO), 'Clone the repo first (see 00_install)'
sys.path.insert(0, os.path.join(REPO, 'src'))
os.environ['RIEMANN_GFM_DATA_ROOT'] = '/content/drive/MyDrive/RiemannGFM/data'

# %%
# %cd $REPO
# !python main.py pretrain --config configs/pretrain.yaml \
  --checkpoint /content/drive/MyDrive/RiemannGFM/checkpoints/riemann_gfm.pt

# %% [markdown]
# The checkpoint is now on Drive. Move on to `02_downstream_nc.ipynb` and `03_downstream_lp.ipynb` for evaluation.
